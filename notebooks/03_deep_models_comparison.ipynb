# %% [markdown]
# # 03 — Deep Models Comparison
# Compare ArcFace, FaceNet, Dlib on the validation set.

# %%
import sys; sys.path.insert(0, "..")
from src.recognition import ArcFaceEncoder, FaceNetEncoder, DlibEncoder

# %%
# TODO: load validation images, encode, compare cosine similarities
