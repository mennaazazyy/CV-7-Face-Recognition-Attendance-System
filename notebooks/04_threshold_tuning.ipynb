# %% [markdown]
# # 04 — Threshold Tuning
# Sweep thresholds, pick best operating point per model.

# %%
import sys; sys.path.insert(0, "..")
import numpy as np
from src.config import THRESHOLDS

# %%
# Run: python scripts/threshold_tuning.py --encoder arcface
