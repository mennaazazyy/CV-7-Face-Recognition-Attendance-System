# %% [markdown]
# # 05 — Final Evaluation
# ROC curves, confusion matrix, FAR/FRR table, bias analysis.

# %%
import sys; sys.path.insert(0, "..")
from src.utils.metrics import roc_data, compute_far_frr
from src.utils.visualization import plot_roc_curves, plot_confusion_matrix

# %%
# TODO: load test-set results from experiments/results.csv and plot
