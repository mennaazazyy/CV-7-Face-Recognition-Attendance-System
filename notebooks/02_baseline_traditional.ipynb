# %% [markdown]
# # 02 — Baseline: Traditional Methods
# Evaluate LBPH, Eigenfaces, Fisherfaces on the validation set.

# %%
import sys; sys.path.insert(0, "..")
from src.recognition import LBPHEncoder, EigenfacesEncoder, FisherfacesEncoder

# %%
# TODO: load validation images, call encoder.encode(), compute metrics
